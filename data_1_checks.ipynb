# %% [markdown]
# Import modules here

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# API request below. I'm pulling data from the Open Brewery dataset. Seems like a fun one to explore.

# %%
r = requests.get('https://api.openbrewerydb.org/breweries')

# %%
beer_data=r.json()

# %%
df = pd.DataFrame(beer_data)

# %%
df.head()
# Out:
#                                    id                             name  \
# 0          10-56-brewing-company-knox            10-56 Brewing Company
# 1         10-barrel-brewing-co-bend-1             10 Barrel Brewing Co
# 2         10-barrel-brewing-co-bend-2             10 Barrel Brewing Co
# 3  10-barrel-brewing-co-bend-pub-bend  10 Barrel Brewing Co - Bend Pub
# 4    10-barrel-brewing-co-boise-boise     10 Barrel Brewing Co - Boise
#
#   brewery_type                       street address_2 address_3   city  \
# 0        micro                400 Brown Cir      None      None   Knox
# 1        large                62970 18th St      None      None   Bend
# 2        large  1135 NW Galveston Ave Ste B      None      None   Bend
# 3        large             62950 NE 18th St      None      None   Bend
# 4        large             826 W Bannock St      None      None  Boise
#
#      state county_province postal_code        country            longitude  \
# ...

# %% [markdown]
# Looks like this dataset only lets me pull 20 entries at a time, so this is a smaller dataset than I was expecting. I can still work with this.

# %%
df.describe()
# Out:
#                                 id                  name brewery_type  \
# count                           20                    20           20
# unique                          20                    17            4
# top     10-56-brewing-company-knox  10 Barrel Brewing Co        micro
# freq                             1                     4            9
#
#                street address_2 address_3  city   state county_province  \
# count              19         1         0    20      19               1
# unique             19         1         0    18      12               1
# top     400 Brown Cir  Clonmore       NaN  Bend  Oregon           Laois
# freq                1         1       NaN     3       5               1
#
#        postal_code        country   longitude   latitude       phone  \
# count           20             20          18         18          19
# unique          20              2          18         18          17
# ...

# %% [markdown]
# Analysis 1: Write a query to select a particular set of your data: I want to see what the different brewery types are.

# %%
df[['brewery_type']]
# Out:
#    brewery_type
# 0         micro
# 1         large
# 2         large
# 3         large
# 4         large
# 5         large
# 6         large
# 7         large
# 8         micro
# 9       brewpub
# 10       closed
# 11        micro
# 12        micro
# 13        micro
# 14        micro
# 15      brewpub
# 16        micro
# 17      brewpub
# 18        micro
# 19        micro

# %% [markdown]
# Descriptive Analysis 2: Some kind of statistics about this dataset -
# Question: What is the most common brewery type?
# Answer: Using mode for this analysis. Looks like it's microbrewery.

# %%
df.brewery_type.mode()
# Out:
# 0    micro
# Name: brewery_type, dtype: object

# %% [markdown]
# Descriptive Analysis 3: Another kind of statistics about this dataset -
# Question: What is the median of the longitude column?
# (This is really kind of a pointless analysis, I just want to see how negative numbers are treated here. Apparently they're fine and I need more coffee.)

# %%
df.longitude.median()
# Out:
# -116.66626099999999

# %% [markdown]
# Analysis 4: Select and print the SECOND AND THIRD columns of your data frame

# %%
df[['name','brewery_type']]
# Out:
#                                              name brewery_type
# 0                           10-56 Brewing Company        micro
# 1                            10 Barrel Brewing Co        large
# 2                            10 Barrel Brewing Co        large
# 3                 10 Barrel Brewing Co - Bend Pub        large
# 4                    10 Barrel Brewing Co - Boise        large
# 5                   10 Barrel Brewing Co - Denver        large
# 6                            10 Barrel Brewing Co        large
# 7                            10 Barrel Brewing Co        large
# 8                  10 Torr Distilling and Brewing        micro
# 9                                     101 Brewery      brewpub
# 10                      101 North Brewing Company       closed
# 11                            105 West Brewing Co        micro
# 12                                    10K Brewing        micro
# 13                  10th District Brewing Company        micro
# ...

# %% [markdown]
# Maybe with column numbers now? Because I know I won't always check what my column names are.

# %%
df.iloc[:,[1,2]]
# Out:
#                                              name brewery_type
# 0                           10-56 Brewing Company        micro
# 1                            10 Barrel Brewing Co        large
# 2                            10 Barrel Brewing Co        large
# 3                 10 Barrel Brewing Co - Bend Pub        large
# 4                    10 Barrel Brewing Co - Boise        large
# 5                   10 Barrel Brewing Co - Denver        large
# 6                            10 Barrel Brewing Co        large
# 7                            10 Barrel Brewing Co        large
# 8                  10 Torr Distilling and Brewing        micro
# 9                                     101 Brewery      brewpub
# 10                      101 North Brewing Company       closed
# 11                            105 West Brewing Co        micro
# 12                                    10K Brewing        micro
# 13                  10th District Brewing Company        micro
# ...

# %% [markdown]
# Analysis 5: Select and print the FIRST 4 rows of you data frame.

# %%
df.iloc[0:4]
# Out:
#                                    id                             name  \
# 0          10-56-brewing-company-knox            10-56 Brewing Company
# 1         10-barrel-brewing-co-bend-1             10 Barrel Brewing Co
# 2         10-barrel-brewing-co-bend-2             10 Barrel Brewing Co
# 3  10-barrel-brewing-co-bend-pub-bend  10 Barrel Brewing Co - Bend Pub
#
#   brewery_type                       street address_2 address_3  city  \
# 0        micro                400 Brown Cir      None      None  Knox
# 1        large                62970 18th St      None      None  Bend
# 2        large  1135 NW Galveston Ave Ste B      None      None  Bend
# 3        large             62950 NE 18th St      None      None  Bend
#
#      state county_province postal_code        country            longitude  \
# 0  Indiana            None       46534  United States           -86.627954
# 1   Oregon            None  97701-9847  United States  -121.28170597038259
# ...
